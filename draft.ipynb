# %%
import pandas as pd
import talib
from datetime import datetime
import itertools

# %%
from data_processor.indicator import add_tech_indicator

# %%
price_df = pd.read_csv("./data/TEST_2019-01-01~2020-05-01_price.csv")
fund_df = pd.read_csv("./data/TEST_2019-01-01~2020-05-01_fund.csv")

# %%
price = price_df[price_df['tic'] == 'sh.600000'].reset_index(drop=True)
fund = fund_df[fund_df['tic'] == 'sh.600000'].reset_index(drop=True)

# %%
price['date'] = pd.to_datetime(price['date'])

# %%
fund['date'] = pd.to_datetime(fund['date'])

# %%
date = price['date'].unique().tolist()
date
# Out:
# ['2019-01-02',
#  '2019-01-03',
#  '2019-01-04',
#  '2019-01-07',
#  '2019-01-08',
#  '2019-01-09',
#  '2019-01-10',
#  '2019-01-11',
#  '2019-01-14',
#  '2019-01-15',
#  '2019-01-16',
#  '2019-01-17',
#  '2019-01-18',
#  '2019-01-21',
#  '2019-01-22',
#  '2019-01-23',
#  '2019-01-24',
#  '2019-01-25',
#  '2019-01-28',
#  '2019-01-29',
#  '2019-01-30',
#  '2019-01-31',
#  '2019-02-01',
#  '2019-02-11',
#  '2019-02-12',
#  '2019-02-13',
#  '2019-02-14',
#  '2019-02-15',
#  '2019-02-18',
#  '2019-02-19',
#  '2019-02-20',
#  '2019-02-21',
#  '2019-02-22',
#  '2019-02-25',
#  '2019-02-26',
#  '2019-02-27',
#  '2019-02-28',
#  '2019-03-01',
#  '2019-03-04',
#  '2019-03-05',
#  '2019-03-06',
#  '2019-03-07',
#  '2019-03-08',
#  '2019-03-11',
#  '2019-03-12',
#  '2019-03-13',
#  '2019-03-14',
#  '2019-03-15',
#  '2019-03-18',
#  '2019-03-19',
#  '2019-03-20',
#  '2019-03-21',
#  '2019-03-22',
#  '2019-03-25',
#  '2019-03-26',
#  '2019-03-27',
#  '2019-03-28',
#  '2019-03-29',
# ...

# %%
list_date = list(pd.date_range(price['date'].min(), price['date'].max()))

# %%
process = pd.DataFrame(list_date, columns=['date']).merge(price, on='date', how='left')

# %%
process = process.merge(fund.drop(index=3), how="left", on=['date'])

# %%
fund.drop(index=3)
# Out:
#    Unnamed: 0        tic       date       ROE  AssetStoEquity   Pnitoni  \
# 0           0  sh.600000 2019-04-30  0.034284       13.371919  0.990015
# 1           1  sh.600000 2019-08-24  0.066587       13.428551  0.990590
# 2           2  sh.600000 2019-10-30  0.095587       12.929761  0.989481
# 4           4  sh.600000 2020-04-25  0.030746       12.668370  0.990359
# 5           5  sh.600000 2020-08-29  0.051763       12.984997  0.989779
# 6           6  sh.600000 2020-10-31  0.079413       13.028267  0.990086
# 7           7  sh.600000 2021-03-27  0.097856       12.546493  0.988677
#
#      Nitogr  TaxBurden
# 0  0.331942   0.860641
# 1  0.332083   0.848056
# 2  0.333802   0.846423
# 4  0.316289   0.846615
# 5  0.288481   0.871537
# 6  0.303837   0.875232
# 7  0.300396   0.884692

# %%
process.tail(10)
# Out:
#           date      tic_x   open   high    low  close       amount  \
# 475 2020-04-21  sh.600000  10.07  10.12  10.01  10.03  176508085.0
# 476 2020-04-22  sh.600000  10.02  10.07   9.98  10.07  158372535.0
# 477 2020-04-23  sh.600000  10.10  10.10  10.01  10.06  169579075.0
# 478 2020-04-24  sh.600000  10.06  10.09  10.01  10.06  170599170.0
# 479 2020-04-25        NaN    NaN    NaN    NaN    NaN          NaN
# 480 2020-04-26        NaN    NaN    NaN    NaN    NaN          NaN
# 481 2020-04-27  sh.600000  10.15  10.42  10.15  10.34  520243997.0
# 482 2020-04-28  sh.600000  10.36  10.38  10.22  10.33  301584635.0
# 483 2020-04-29  sh.600000  10.35  10.61  10.33  10.61  367739389.0
# 484 2020-04-30  sh.600000  10.58  10.79  10.56  10.63  330157488.0
#
#      Unnamed: 0      tic_y       ROE  AssetStoEquity   Pnitoni    Nitogr  \
# 475         NaN        NaN       NaN             NaN       NaN       NaN
# 476         NaN        NaN       NaN             NaN       NaN       NaN
# ...
